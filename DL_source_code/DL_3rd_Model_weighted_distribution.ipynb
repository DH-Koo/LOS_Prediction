# %%
import pandas as pd
from collections import Counter
import json
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np

df = pd.read_parquet("los_dataset_24h.parquet")

print(df.shape)
print(df.columns)
# Out:
# (424803, 17)
# Index(['subject_id', 'hadm_id', 'admittime', 'dischtime', 'race', 'los_hours',
#        'gender', 'anchor_age', 'curr_service', 'hcpcs_cd_list',
#        'diagnoses_icd_code_list', 'procedures_icd_code_list', 'drg_code',
#        'drg_severity', 'drg_mortality', 'medication_list', 'order_type_list'],
#       dtype='object')

# %%
def build_label_encoder(series):
    classes = sorted(series.unique())
    stoi = {c: i for i, c in enumerate(classes)}
    return stoi


def build_vocab_from_list_column(df, col, min_freq=1, add_unk=True):
    counter = Counter()
    for lst in df[col]:
        counter.update(lst)

    stoi = {}
    idx = 0
    if add_unk:
        stoi["<UNK>"] = idx
        idx += 1

    for token, freq in counter.items():
        if freq >= min_freq:
            if token not in stoi:
                stoi[token] = idx
                idx += 1

    return stoi

# %%
# Encoders for gender, race, curr_service, drg_code
gender_stoi = build_label_encoder(df["gender"])
race_stoi = build_label_encoder(df["race"])
service_stoi = build_label_encoder(df["curr_service"])

# drg_code is already an int, but treat it as a "category" and remap to index
drg_code_stoi = build_label_encoder(df["drg_code"].astype(int))

print("num_genders:", len(gender_stoi))
print("num_races:", len(race_stoi))
print("num_services:", len(service_stoi))
print("num_drg_codes:", len(drg_code_stoi))
# Out:
# num_genders: 2
# num_races: 33
# num_services: 21
# num_drg_codes: 301

# %%
list_cols = [
    "diagnoses_icd_code_list",
    "procedures_icd_code_list",
    "hcpcs_cd_list",
    "medication_list",
    "order_type_list",
]

diag_stoi = build_vocab_from_list_column(df, "diagnoses_icd_code_list", min_freq=1)
proc_stoi = build_vocab_from_list_column(df, "procedures_icd_code_list", min_freq=1)
hcpcs_stoi = build_vocab_from_list_column(df, "hcpcs_cd_list", min_freq=1)
med_stoi = build_vocab_from_list_column(df, "medication_list", min_freq=1)
order_stoi = build_vocab_from_list_column(df, "order_type_list", min_freq=1)

print("diag vocab size:", len(diag_stoi))
print("proc vocab size:", len(proc_stoi))
print("hcpcs vocab size:", len(hcpcs_stoi))
print("med vocab size:", len(med_stoi))
print("order vocab size:", len(order_stoi))
# Out:
# diag vocab size: 27701
# proc vocab size: 12184
# hcpcs vocab size: 1925
# med vocab size: 3358
# order vocab size: 17

# %%
# Combine proc_stoi and hcpcs_stoi into a single unified vocab
proc_all_stoi = {}
idx = 0

# Only one UNK
proc_all_stoi["<UNK>"] = idx
idx += 1

# Procedures first
for k in proc_stoi.keys():
    if k == "<UNK>":
        continue
    proc_all_stoi["PROC_" + k] = idx
    idx += 1

# HCPCS next
for k in hcpcs_stoi.keys():
    if k == "<UNK>":
        continue
    key = "HCPCS_" + k
    if key not in proc_all_stoi:
        proc_all_stoi[key] = idx
        idx += 1

print("combined proc vocab size:", len(proc_all_stoi))
# Out:
# combined proc vocab size: 14108

# %%
UNK_DIAG = diag_stoi["<UNK>"]
UNK_PROC = proc_all_stoi["<UNK>"]
UNK_MED = med_stoi["<UNK>"]
UNK_ORDER = order_stoi["<UNK>"]

def map_list_to_ids(lst, stoi, unk_token="<UNK>"):
    unk_idx = stoi.get(unk_token, None)
    out = []
    for x in lst:
        idx = stoi.get(x)
        if idx is None:
            if unk_idx is not None:
                out.append(unk_idx)
            # If UNK is not present, can just skip
        else:
            out.append(idx)
    return out

# Diagnostic codes
df["diag_ids"] = df["diagnoses_icd_code_list"].apply(
    lambda lst: map_list_to_ids(lst, diag_stoi)
)

# Combined procedure + hcpcs ids
def build_proc_ids(row):
    ids = []
    for code in row["procedures_icd_code_list"]:
        tok = "PROC_" + code
        ids.append(proc_all_stoi.get(tok, UNK_PROC))
    for code in row["hcpcs_cd_list"]:
        tok = "HCPCS_" + code
        ids.append(proc_all_stoi.get(tok, UNK_PROC))
    return ids

df["proc_ids"] = df.apply(build_proc_ids, axis=1)

# Medication
df["med_ids"] = df["medication_list"].apply(
    lambda lst: map_list_to_ids(lst, med_stoi)
)

# Order_type
df["order_ids"] = df["order_type_list"].apply(
    lambda lst: map_list_to_ids(lst, order_stoi)
)

# Single categorical -> id
df["gender_id"] = df["gender"].map(gender_stoi)
df["race_id"] = df["race"].map(race_stoi)
df["service_id"] = df["curr_service"].map(service_stoi)
df["drg_code_id"] = df["drg_code"].astype(int).map(drg_code_stoi)

# %%
def summarize_list(lst, max_len=10):
    """
    Summarizes a list by truncating it if it's too long.
    """
    if lst is None:
        return None
    if len(lst) <= max_len:
        return lst
    return lst[:max_len] + ["...(+{} more)".format(len(lst) - max_len)]


# Print 3 samples
cols_to_show = [
    "gender", "race", "curr_service", "drg_code",
    "gender_id", "race_id", "service_id", "drg_code_id",
    "diagnoses_icd_code_list", "diag_ids",
    "procedures_icd_code_list", "hcpcs_cd_list", "proc_ids",
    "medication_list", "med_ids",
    "order_type_list", "order_ids",
]

print("\n================ SAMPLE DATA (after encoding) ================\n")

for i in range(3):
    row = df.iloc[i]
    print(f"--- Row {i} ---")

    for c in cols_to_show:
        val = row[c]

        # Summarize list
        if isinstance(val, list):
            val = summarize_list(val)

        print(f"{c:25} : {val}")

    print("\n")
# Out:
# ================ SAMPLE DATA (after encoding) ================
#
# --- Row 0 ---
# gender                    : F
# race                      : WHITE
# curr_service              : MED
# drg_code                  : 279
# gender_id                 : 0
# race_id                   : 28
# service_id                : 7
# drg_code_id               : 135
# diagnoses_icd_code_list   : ['07071' '78959' '2875' '2761' '496' '5715' 'V08' '3051']
# diag_ids                  : [1, 2, 3, 4, 5, 6, 7, 8]
# procedures_icd_code_list  : ['5491']
# hcpcs_cd_list             : []
# proc_ids                  : [1]
# medication_list           : ['Raltegravir' 'Rifaximin' 'Sodium Chloride 0.9%  Flush'
#  'Calcium Carbonate' 'Rifaximin' 'Raltegravir'
#  'Emtricitabine-Tenofovir (Truvada)' 'Sulfameth/Trimethoprim DS'
#  'Furosemide' 'Tiotropium Bromide' 'Albuterol Inhaler' 'Lactulose'
#  'Heparin' 'Sodium Chloride 0.9%  Flush' 'Acetaminophen' 'Heparin'
#  'Lactulose' 'Albumin 25% (12.5g / 50mL)' 'Sodium Chloride 0.9%  Flush'
#  'Albumin 25% (12.5g / 50mL)' 'Albumin 25% (12.5g / 50mL)']
# med_ids                   : [1, 2, 3, 4, 2, 1, 5, 6, 7, 8, '...(+11 more)']
# order_type_list           : ['Medications' 'General Care' 'Nutrition' 'Blood Bank' 'Lab' 'Respiratory'
#  'Medications' 'Medications' 'ADT orders' 'Lab' 'Lab' 'Medications'
#  'ADT orders' 'ADT orders' 'ADT orders' 'ADT orders' 'Lab' 'ADT orders'
#  'Lab' 'General Care' 'Nutrition' 'Medications' 'ADT orders' 'Lab'
#  'IV therapy' 'Medications' 'General Care' 'General Care' 'Nutrition'
#  'Medications' 'Nutrition' 'Lab' 'Medications' 'Medications' 'Medications'
#  'Medications' 'Medications' 'Medications' 'Medications' 'Medications'
#  'Medications' 'Medications']
# order_ids                 : [1, 2, 3, 4, 5, 6, 1, 1, 7, 5, '...(+32 more)']
#
#
# --- Row 1 ---
# gender                    : F
# race                      : WHITE
# curr_service              : MED
# drg_code                  : 283
# gender_id                 : 0
# race_id                   : 28
# service_id                : 7
# drg_code_id               : 139
# diagnoses_icd_code_list   : ['07054' '78959' 'V462' '5715' '2767' '2761' '496' 'V08' '3051' '78791']
# diag_ids                  : [9, 2, 10, 6, 11, 4, 5, 7, 8, 12]
# procedures_icd_code_list  : ['5491']
# hcpcs_cd_list             : []
# proc_ids                  : [1]
# medication_list           : ['Heparin' 'Raltegravir' 'Rifaximin' 'Emtricitabine-Tenofovir (Truvada)'
#  'Lactulose' 'Fluticasone Propionate 110mcg' 'Tiotropium Bromide'
#  'Albuterol Inhaler' 'Calcium Gluconate' 'Dextrose 50%'
#  'Insulin (Regular) for Hyperkalemia' 'Sodium Polystyrene Sulfonate'
#  'TraMADOL (Ultram)' 'Lactulose' 'Heparin' 'Sodium Chloride 0.9%  Flush'
#  'Lactulose' 'Albuterol Inhaler' 'Insulin (Regular) for Hyperkalemia'
#  'Sodium Polystyrene Sulfonate' 'Calcium Gluconate' 'Dextrose 50%'
#  'Furosemide' 'Albumin 25% (12.5g / 50mL)' 'Calcium Carbonate'
#  'Raltegravir' 'Rifaximin' 'Zolpidem Tartrate'
#  'Fluticasone Propionate 110mcg' 'Albuterol Inhaler' 'Heparin'
#  'Sodium Chloride 0.9%  Flush' 'Sodium Chloride 0.9%  Flush'
#  'Calcium Carbonate']
# med_ids                   : [11, 1, 2, 5, 10, 14, 8, 9, 15, 16, '...(+24 more)']
# order_type_list           : ['Lab' 'ADT orders' 'Lab' 'General Care' 'General Care' 'Nutrition'
#  'Medications' 'ADT orders' 'Lab' 'IV therapy' 'Medications'
#  'General Care' 'General Care' 'General Care' 'Lab' 'Medications'
#  'Medications' 'Medications' 'Medications' 'Medications' 'Medications'
#  'Medications' 'Medications' 'Medications' 'Medications' 'Medications'
#  'Radiology' 'Nutrition' 'Nutrition' 'ADT orders' 'Lab' 'Medications'
#  'Medications' 'Medications' 'Medications' 'Cardiology' 'Lab'
#  'Medications' 'Consults' 'Consults' 'General Care' 'Medications' 'Lab'
#  'Medications' 'Lab' 'Lab' 'Medications' 'Medications' 'Medications'
#  'Medications' 'General Care' 'General Care' 'Medications' 'Medications'
#  'Lab']
# order_ids                 : [5, 7, 5, 2, 2, 3, 1, 7, 5, 8, '...(+45 more)']
#
#
# --- Row 2 ---
# gender                    : F
# race                      : WHITE
# curr_service              : MED
# drg_code                  : 207
# gender_id                 : 0
# race_id                   : 28
# service_id                : 7
# drg_code_id               : 103
# diagnoses_icd_code_list   : ['45829' '07044' '7994' '2761' '78959' '2767' '3051' 'V08' 'V4986' 'V462'
#  '496' '29680' '5715']
# diag_ids                  : [13, 14, 15, 4, 2, 11, 8, 7, 16, 10, '...(+3 more)']
# procedures_icd_code_list  : []
# hcpcs_cd_list             : []
# proc_ids                  : []
# medication_list           : ['Lactulose' 'TraMADOL (Ultram)' 'Sodium Chloride 0.9%  Flush'
#  'Albumin 25% (12.5g / 50mL)' 'Bisacodyl' 'Calcium Carbonate'
#  'Docusate Sodium (Liquid)' 'Emtricitabine-Tenofovir (Truvada)'
#  'Fluticasone Propionate 110mcg' 'Heparin' 'Lactulose' 'Raltegravir'
#  'Rifaximin' 'Tiotropium Bromide']
# med_ids                   : [10, 19, 3, 13, 21, 4, 22, 5, 14, 11, '...(+4 more)']
# order_type_list           : ['Lab' 'ADT orders' 'Lab' 'General Care' 'General Care' 'General Care'
#  'Nutrition' 'Medications' 'ADT orders' 'Lab' 'General Care'
#  'General Care' 'General Care' 'Nutrition' 'Medications' 'Medications'
#  'Medications' 'General Care' 'Medications' 'Respiratory' 'General Care'
#  'Lab' 'Medications' 'Lab' 'Nutrition' 'Medications' 'Lab' 'Medications'
#  'Medications' 'Medications' 'Medications' 'Medications' 'Medications'
#  'Medications' 'Lab' 'ADT orders' 'Lab' 'Medications' 'Medications'
#  'Medications' 'Medications' 'Medications' 'Medications' 'Medications'
#  'Medications' 'Medications' 'Medications' 'Medications' 'Medications'
#  'Nutrition' 'Nutrition' 'IV therapy' 'Medications' 'General Care'
#  'General Care' 'General Care' 'Lab' 'General Care' 'Medications'
#  'Medications' 'Lab' 'General Care' 'ADT orders' 'Lab' 'Medications'
#  'Consults' 'Consults' 'Medications' 'Medications' 'Medications'
#  'Medications']
# order_ids                 : [5, 7, 5, 2, 2, 2, 3, 1, 7, 5, '...(+61 more)']

# %%
class LOSDataset(Dataset):
    def __init__(self, df, use_log_target=True):
        self.df = df.reset_index(drop=True)
        self.use_log_target = use_log_target

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]

        sample = {
            # tabular
            "age": float(row["anchor_age"]),
            "gender_id": int(row["gender_id"]),
            "race_id": int(row["race_id"]),
            "service_id": int(row["service_id"]),
            "drg_code_id": int(row["drg_code_id"]),
            "drg_severity": float(row["drg_severity"]),
            "drg_mortality": float(row["drg_mortality"]),

            # List-type IDs
            "diag_ids": row["diag_ids"],
            "proc_ids": row["proc_ids"],
            "med_ids": row["med_ids"],
            "order_ids": row["order_ids"],
        }

        # target
        los = float(row["los_hours"])
        if self.use_log_target:
            sample["target"] = np.log1p(los)
        else:
            sample["target"] = los

        return sample

# %%
def los_collate_fn(batch):
    B = len(batch)

    # ----- Tabular stack -----
    age = torch.tensor([b["age"] for b in batch], dtype=torch.float32)
    gender_id = torch.tensor([b["gender_id"] for b in batch], dtype=torch.long)
    race_id = torch.tensor([b["race_id"] for b in batch], dtype=torch.long)
    service_id = torch.tensor([b["service_id"] for b in batch], dtype=torch.long)
    drg_code_id = torch.tensor([b["drg_code_id"] for b in batch], dtype=torch.long)
    drg_severity = torch.tensor([b["drg_severity"] for b in batch], dtype=torch.float32)
    drg_mortality = torch.tensor([b["drg_mortality"] for b in batch], dtype=torch.float32)

    target = torch.tensor([b["target"] for b in batch], dtype=torch.float32)

    # ----- List-type: diag / proc / med / order -----
    def build_bag_inputs(key):
        codes_all = []
        offsets = [0]
        for b in batch:
            ids = b[key]
            codes_all.extend(ids)
            offsets.append(len(codes_all))
        if len(codes_all) == 0:
            # Handle cases where the list is empty for all admissions
            codes_tensor = torch.empty(0, dtype=torch.long)
        else:
            codes_tensor = torch.tensor(codes_all, dtype=torch.long)
        offsets_tensor = torch.tensor(offsets, dtype=torch.long)
        return codes_tensor, offsets_tensor

    diag_codes, diag_offsets = build_bag_inputs("diag_ids")
    proc_codes, proc_offsets = build_bag_inputs("proc_ids")
    med_codes, med_offsets = build_bag_inputs("med_ids")
    order_codes, order_offsets = build_bag_inputs("order_ids")

    batch_out = {
        "age": age,
        "gender_id": gender_id,
        "race_id": race_id,
        "service_id": service_id,
        "drg_code_id": drg_code_id,
        "drg_severity": drg_severity,
        "drg_mortality": drg_mortality,
        "diag_codes": diag_codes,
        "diag_offsets": diag_offsets,
        "proc_codes": proc_codes,
        "proc_offsets": proc_offsets,
        "med_codes": med_codes,
        "med_offsets": med_offsets,
        "order_codes": order_codes,
        "order_offsets": order_offsets,
        "target": target,
    }

    return batch_out

# %%
from torch.utils.data import random_split, DataLoader
import torch

# Create Dataset
dataset = LOSDataset(df, use_log_target=True)

n_total = len(dataset)
n_train = int(n_total * 0.7)
n_val = int(n_total * 0.15)
n_test = n_total - n_train - n_val   # Remaining

g = torch.Generator().manual_seed(42)
train_ds, val_ds, test_ds = random_split(dataset, [n_train, n_val, n_test], generator=g)

train_loader = DataLoader(
    train_ds,
    batch_size=256,
    shuffle=True,
    collate_fn=los_collate_fn,
)

val_loader = DataLoader(
    val_ds,
    batch_size=256,
    shuffle=False,
    collate_fn=los_collate_fn,
)

test_loader = DataLoader(
    test_ds,
    batch_size=256,
    shuffle=False,
    collate_fn=los_collate_fn,
)

print(f"#train: {len(train_ds)}, #val: {len(val_ds)}, #test: {len(test_ds)}")
# Out:
# #train: 297362, #val: 63720, #test: 63721

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from dataclasses import dataclass


@dataclass
class ModelConfig:
    # ----- Tabular categorical vocab sizes -----
    num_genders: int          # e.g. {"M", "F"} -> 2
    num_races: int            # unique race categories
    num_services: int         # curr_service (MED, ORTHO, ...)
    num_drg_codes: int        # drg_code vocab size

    # ----- Code vocab sizes -----
    diag_vocab_size: int      # diagnoses_icd_code_list vocab
    proc_vocab_size: int      # procedures_icd_code_list + hcpcs_cd_list integrated vocab
    med_vocab_size: int       # medication_list vocab
    order_vocab_size: int     # order_type_list vocab

    # ----- Embedding dimensions -----
    emb_dim_gender: int = 4
    emb_dim_race: int = 8
    emb_dim_service: int = 8
    emb_dim_drg: int = 16

    emb_dim_diag: int = 32
    emb_dim_proc: int = 32
    emb_dim_med: int = 32
    emb_dim_order: int = 16

    # ----- Hidden dimension for the single MLP -----
    hidden_dim: int = 128 # This will be the hidden dimension for the combined MLP
    dropout: float = 0.2


class MultiModalLOSModel(nn.Module):
    def __init__(self, cfg: ModelConfig):
        super().__init__()
        self.cfg = cfg

        # ------------- Embeddings for all categorical and list features -------------
        self.gender_emb = nn.Embedding(cfg.num_genders, cfg.emb_dim_gender)
        self.race_emb = nn.Embedding(cfg.num_races, cfg.emb_dim_race)
        self.service_emb = nn.Embedding(cfg.num_services, cfg.emb_dim_service)
        self.drg_emb = nn.Embedding(cfg.num_drg_codes, cfg.emb_dim_drg)

        self.diag_emb = nn.EmbeddingBag(
            cfg.diag_vocab_size, cfg.emb_dim_diag,
            mode="mean", include_last_offset=True
        )
        self.proc_emb = nn.EmbeddingBag(
            cfg.proc_vocab_size, cfg.emb_dim_proc,
            mode="mean", include_last_offset=True
        )
        self.med_emb = nn.EmbeddingBag(
            cfg.med_vocab_size, cfg.emb_dim_med,
            mode="mean", include_last_offset=True
        )
        self.order_emb = nn.EmbeddingBag(
            cfg.order_vocab_size, cfg.emb_dim_order,
            mode="mean", include_last_offset=True
        )

        # Calculate total input dimension for the single MLP
        total_in_dim = (
            3 # for age, drg_severity, drg_mortality
            + cfg.emb_dim_gender
            + cfg.emb_dim_race
            + cfg.emb_dim_service
            + cfg.emb_dim_drg
            + cfg.emb_dim_diag
            + cfg.emb_dim_proc
            + cfg.emb_dim_med
            + cfg.emb_dim_order
        )

        # Single MLP for all combined features
        self.main_mlp = nn.Sequential(
            nn.Linear(total_in_dim, cfg.hidden_dim),
            nn.ReLU(),
            nn.Dropout(cfg.dropout),
            nn.Linear(cfg.hidden_dim, cfg.hidden_dim),
            nn.ReLU(),
            nn.Dropout(cfg.dropout),
        )

        # Final regression output layer (LOS prediction)
        self.out = nn.Linear(cfg.hidden_dim, 1)

    def forward(
        self,
        # ----- Tabular -----
        age,               # (B,) float tensor (anchor_age or normalized)
        gender_idx,        # (B,) long tensor
        race_idx,          # (B,) long tensor
        service_idx,       # (B,) long tensor (curr_service)
        drg_code_idx,      # (B,) long tensor
        drg_severity,      # (B,) float or long (normalize to float first)
        drg_mortality,     # (B,) float or long

        # ----- Diagnoses (EmbeddingBag) -----
        diag_codes,        # (N_diag_codes,) long tensor (flattened)
        diag_offsets,      # (B+1,) long tensor, offsets for EmbeddingBag

        # ----- Procedures (EmbeddingBag) -----
        proc_codes,        # (N_proc_codes,) long tensor
        proc_offsets,      # (B+1,) long tensor

        # ----- Medications (EmbeddingBag) -----
        med_codes,         # (N_med_codes,) long tensor
        med_offsets,       # (B+1,) long tensor

        # ----- Order types (EmbeddingBag) -----
        order_codes,       # (N_order_codes,) long tensor
        order_offsets,     # (B+1,) long tensor
    ):
        # Embeddings for categorical features
        g_emb = self.gender_emb(gender_idx)   # (B, emb_dim_gender)
        r_emb = self.race_emb(race_idx)       # (B, emb_dim_race)
        s_emb = self.service_emb(service_idx) # (B, emb_dim_service)
        d_emb = self.drg_emb(drg_code_idx)    # (B, emb_dim_drg)

        # EmbeddingBag for list features
        diag_bag = self.diag_emb(diag_codes, diag_offsets)  # (B, emb_dim_diag)
        proc_bag = self.proc_emb(proc_codes, proc_offsets)  # (B, emb_dim_proc)
        med_bag = self.med_emb(med_codes, med_offsets)      # (B, emb_dim_med)
        order_bag = self.order_emb(order_codes, order_offsets) # (B, emb_dim_order)

        # Continuous features (unsqueeze for concatenation)
        age = age.float().unsqueeze(-1)                 # (B, 1)
        sev = drg_severity.float().unsqueeze(-1)        # (B, 1)
        mort = drg_mortality.float().unsqueeze(-1)      # (B, 1)

        # Concatenate all features into a single tensor
        all_features = torch.cat(
            [
                age, sev, mort,
                g_emb, r_emb, s_emb, d_emb,
                diag_bag, proc_bag, med_bag, order_bag
            ],
            dim=-1
        )

        # Pass the combined features through the main MLP
        h = self.main_mlp(all_features)
        out = self.out(h).squeeze(-1)  # (B,)

        return out

# %%
train_los_hours = df.iloc[train_ds.indices]['los_hours'].values

print(f"# Training samples: {len(train_los_hours)}")
print(f"Min LOS (hours): {np.min(train_los_hours):.2f}")
print(f"Max LOS (hours): {np.max(train_los_hours):.2f}")
print(f"Mean LOS (hours): {np.mean(train_los_hours):.2f}")
# Out:
# # Training samples: 297362
# Min LOS (hours): 24.02
# Max LOS (hours): 12373.50
# Mean LOS (hours): 142.76

# %%
sample_weights = np.log1p(train_los_hours)
sample_weights_tensor = torch.tensor(sample_weights, dtype=torch.float)

print(f"# Calculated sample weights: {len(sample_weights_tensor)}")
print(f"Min sample weight: {sample_weights_tensor.min():.4f}")
print(f"Max sample weight: {sample_weights_tensor.max():.4f}")
print(f"Mean sample weight: {sample_weights_tensor.mean():.4f}")
# Out:
# # Calculated sample weights: 297362
# Min sample weight: 3.2195
# Max sample weight: 9.4234
# Mean sample weight: 4.5903

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.hist(train_los_hours, bins=50, edgecolor='black')
plt.title('Distribution of LOS Hours (Training Data)')
plt.xlabel('LOS Hours')
plt.ylabel('Frequency')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.hist(sample_weights, bins=50, edgecolor='black')
plt.title('Distribution of Sample Weights (log1p transformed LOS)')
plt.xlabel('Sample Weight (log1p(LOS_hours))')
plt.ylabel('Frequency')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
from torch.utils.data import WeightedRandomSampler

sampler = WeightedRandomSampler(
    weights=sample_weights_tensor,
    num_samples=len(sample_weights_tensor),
    replacement=True 
)

train_loader_weighted = DataLoader(
    train_ds,
    batch_size=256,
    sampler=sampler,
    collate_fn=los_collate_fn,
)

print(f"Weighted train_loader created with {len(train_loader_weighted.sampler)} samples.")
# Out:
# Weighted train_loader created with 297362 samples.

# %%
cfg = ModelConfig(
    num_genders=len(gender_stoi),
    num_races=len(race_stoi),
    num_services=len(service_stoi),
    num_drg_codes=len(drg_code_stoi),
    diag_vocab_size=len(diag_stoi),
    proc_vocab_size=len(proc_all_stoi),
    med_vocab_size=len(med_stoi),
    order_vocab_size=len(order_stoi),
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_weighted = MultiModalLOSModel(cfg)
model_weighted.to(device)

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model_weighted.parameters(), lr=1e-3, weight_decay=1e-5)

NUM_EPOCHS = 20

best_val_loss_weighted = float("inf")
best_model_path_weighted = "los_multibranch_weighted_best.pt"
print("Using device:", device)

print("\n================ Starting Weighted Training ================\n")

# 2. Training Loop (Weighted)
for epoch in range(1, NUM_EPOCHS + 1):
    # ---------- Train ----------
    model_weighted.train()
    train_loss_sum = 0.0
    train_count = 0

    print(f"\n========== Epoch {epoch}/{NUM_EPOCHS} (Weighted) ==========")

    for batch_idx, batch in enumerate(train_loader_weighted):
        # Move tensors to device
        batch = {k: (v.to(device) if torch.is_tensor(v) else v)
                 for k, v in batch.items()}

        optimizer.zero_grad()

        y_pred = model_weighted(
            age=batch["age"],
            gender_idx=batch["gender_id"],
            race_idx=batch["race_id"],
            service_idx=batch["service_id"],
            drg_code_idx=batch["drg_code_id"],
            drg_severity=batch["drg_severity"],
            drg_mortality=batch["drg_mortality"],
            diag_codes=batch["diag_codes"],
            diag_offsets=batch["diag_offsets"],
            proc_codes=batch["proc_codes"],
            proc_offsets=batch["proc_offsets"],
            med_codes=batch["med_codes"],
            med_offsets=batch["med_offsets"],
            order_codes=batch["order_codes"],
            order_offsets=batch["order_offsets"],
        )

        y_true = batch["target"]  # log(1+LOS)
        loss = criterion(y_pred, y_true)

        loss.backward()
        optimizer.step()

        bs = y_true.size(0)
        train_loss_sum += loss.item() * bs
        train_count += bs

        if batch_idx % 100 == 0:
            avg_loss = train_loss_sum / train_count
            print(f"  [Epoch {epoch} | Step {batch_idx}/{len(train_loader_weighted)}] "
                  f"AvgTrainLoss={avg_loss:.4f}")

    train_loss = train_loss_sum / train_count

    # ---------- Validation ----------
    model_weighted.eval()
    val_loss_sum = 0.0
    val_count = 0
    val_mae_hours_sum = 0.0  # MAE based on actual LOS(hours)

    with torch.no_grad():
        for batch in val_loader:
            batch = {k: (v.to(device) if torch.is_tensor(v) else v)
                     for k, v in batch.items()}

            y_pred = model_weighted(
                age=batch["age"],
                gender_idx=batch["gender_id"],
                race_idx=batch["race_id"],
                service_idx=batch["service_id"],
                drg_code_idx=batch["drg_code_id"],
                drg_severity=batch["drg_severity"],
                drg_mortality=batch["drg_mortality"],
                diag_codes=batch["diag_codes"],
                diag_offsets=batch["diag_offsets"],
                proc_codes=batch["proc_codes"],
                proc_offsets=batch["proc_offsets"],
                med_codes=batch["med_codes"],
                med_offsets=batch["med_offsets"],
                order_codes=batch["order_codes"],
                order_offsets=batch["order_offsets"],
            )

            y_true = batch["target"]

            loss = criterion(y_pred, y_true)

            bs = y_true.size(0)
            val_loss_sum += loss.item() * bs
            val_count += bs

            # Convert log(1+LOS) -> actual LOS(hours) and calculate MAE
            y_true_hours = torch.expm1(y_true)
            y_pred_hours = torch.expm1(y_pred)

            mae_hours = torch.abs(y_pred_hours - y_true_hours).sum().item()
            val_mae_hours_sum += mae_hours

    val_loss = val_loss_sum / val_count
    val_mae_hours = val_mae_hours_sum / val_count

    print(f"[Epoch {epoch:03d}] "
          f"train_loss(log-MSE)={train_loss:.4f} | "
          f"val_loss(log-MSE)={val_loss:.4f} | "
          f"val_MAE(hours)={val_mae_hours:.2f}")

    # Save best model
    if val_loss < best_val_loss_weighted:
        best_val_loss_weighted = val_loss
        torch.save(model_weighted.state_dict(), best_model_path_weighted)
        print(f"  ↳ Best weighted model updated, saved to {best_model_path_weighted}")

print("Weighted training finished. Best val_loss:", best_val_loss_weighted)
# Out:
# Using device: cuda
#
# ================ Starting Weighted Training ================
#
#
# ========== Epoch 1/20 (Weighted) ==========
#   [Epoch 1 | Step 0/1162] AvgTrainLoss=22.8381
#   [Epoch 1 | Step 100/1162] AvgTrainLoss=2.4698
#   [Epoch 1 | Step 200/1162] AvgTrainLoss=1.6098
#   [Epoch 1 | Step 300/1162] AvgTrainLoss=1.2925
#   [Epoch 1 | Step 400/1162] AvgTrainLoss=1.1288
#   [Epoch 1 | Step 500/1162] AvgTrainLoss=1.0200
#   [Epoch 1 | Step 600/1162] AvgTrainLoss=0.9464
#   [Epoch 1 | Step 700/1162] AvgTrainLoss=0.8899
#   [Epoch 1 | Step 800/1162] AvgTrainLoss=0.8457
#   [Epoch 1 | Step 900/1162] AvgTrainLoss=0.8088
#   [Epoch 1 | Step 1000/1162] AvgTrainLoss=0.7792
#   [Epoch 1 | Step 1100/1162] AvgTrainLoss=0.7538
# [Epoch 001] train_loss(log-MSE)=0.7396 | val_loss(log-MSE)=0.3308 | val_MAE(hours)=66.99
#   ↳ Best weighted model updated, saved to los_multibranch_weighted_best.pt
#
# ========== Epoch 2/20 (Weighted) ==========
#   [Epoch 2 | Step 0/1162] AvgTrainLoss=0.4102
#   [Epoch 2 | Step 100/1162] AvgTrainLoss=0.4879
#   [Epoch 2 | Step 200/1162] AvgTrainLoss=0.4861
#   [Epoch 2 | Step 300/1162] AvgTrainLoss=0.4802
#   [Epoch 2 | Step 400/1162] AvgTrainLoss=0.4748
#   [Epoch 2 | Step 500/1162] AvgTrainLoss=0.4709
#   [Epoch 2 | Step 600/1162] AvgTrainLoss=0.4668
#   [Epoch 2 | Step 700/1162] AvgTrainLoss=0.4637
#   [Epoch 2 | Step 800/1162] AvgTrainLoss=0.4604
#   [Epoch 2 | Step 900/1162] AvgTrainLoss=0.4575
#   [Epoch 2 | Step 1000/1162] AvgTrainLoss=0.4541
#   [Epoch 2 | Step 1100/1162] AvgTrainLoss=0.4509
# [Epoch 002] train_loss(log-MSE)=0.4494 | val_loss(log-MSE)=0.3022 | val_MAE(hours)=64.15
#   ↳ Best weighted model updated, saved to los_multibranch_weighted_best.pt
#
# ========== Epoch 3/20 (Weighted) ==========
#   [Epoch 3 | Step 0/1162] AvgTrainLoss=0.4753
#   [Epoch 3 | Step 100/1162] AvgTrainLoss=0.4140
#   [Epoch 3 | Step 200/1162] AvgTrainLoss=0.4079
#   [Epoch 3 | Step 300/1162] AvgTrainLoss=0.4102
#   [Epoch 3 | Step 400/1162] AvgTrainLoss=0.4072
#   [Epoch 3 | Step 500/1162] AvgTrainLoss=0.4058
#   [Epoch 3 | Step 600/1162] AvgTrainLoss=0.4040
#   [Epoch 3 | Step 700/1162] AvgTrainLoss=0.4019
#   [Epoch 3 | Step 800/1162] AvgTrainLoss=0.3994
#   [Epoch 3 | Step 900/1162] AvgTrainLoss=0.3976
#   [Epoch 3 | Step 1000/1162] AvgTrainLoss=0.3959
#   [Epoch 3 | Step 1100/1162] AvgTrainLoss=0.3940
# [Epoch 003] train_loss(log-MSE)=0.3929 | val_loss(log-MSE)=0.2874 | val_MAE(hours)=62.78
#   ↳ Best weighted model updated, saved to los_multibranch_weighted_best.pt
#
# ========== Epoch 4/20 (Weighted) ==========
#   [Epoch 4 | Step 0/1162] AvgTrainLoss=0.3727
#   [Epoch 4 | Step 100/1162] AvgTrainLoss=0.3725
#   [Epoch 4 | Step 200/1162] AvgTrainLoss=0.3666
#   [Epoch 4 | Step 300/1162] AvgTrainLoss=0.3653
#   [Epoch 4 | Step 400/1162] AvgTrainLoss=0.3641
#   [Epoch 4 | Step 500/1162] AvgTrainLoss=0.3651
#   [Epoch 4 | Step 600/1162] AvgTrainLoss=0.3650
#   [Epoch 4 | Step 700/1162] AvgTrainLoss=0.3636
#   [Epoch 4 | Step 800/1162] AvgTrainLoss=0.3620
#   [Epoch 4 | Step 900/1162] AvgTrainLoss=0.3607
#   [Epoch 4 | Step 1000/1162] AvgTrainLoss=0.3599
#   [Epoch 4 | Step 1100/1162] AvgTrainLoss=0.3582
# [Epoch 004] train_loss(log-MSE)=0.3576 | val_loss(log-MSE)=0.2838 | val_MAE(hours)=62.24
#   ↳ Best weighted model updated, saved to los_multibranch_weighted_best.pt
#
# ========== Epoch 5/20 (Weighted) ==========
#   [Epoch 5 | Step 0/1162] AvgTrainLoss=0.3411
#   [Epoch 5 | Step 100/1162] AvgTrainLoss=0.3465
#   [Epoch 5 | Step 200/1162] AvgTrainLoss=0.3460
#   [Epoch 5 | Step 300/1162] AvgTrainLoss=0.3447
#   [Epoch 5 | Step 400/1162] AvgTrainLoss=0.3447
#   [Epoch 5 | Step 500/1162] AvgTrainLoss=0.3425
#   [Epoch 5 | Step 600/1162] AvgTrainLoss=0.3408
#   [Epoch 5 | Step 700/1162] AvgTrainLoss=0.3407
#   [Epoch 5 | Step 800/1162] AvgTrainLoss=0.3399
#   [Epoch 5 | Step 900/1162] AvgTrainLoss=0.3396
#   [Epoch 5 | Step 1000/1162] AvgTrainLoss=0.3383
#   [Epoch 5 | Step 1100/1162] AvgTrainLoss=0.3371
# [Epoch 005] train_loss(log-MSE)=0.3368 | val_loss(log-MSE)=0.2950 | val_MAE(hours)=64.02
#
# ========== Epoch 6/20 (Weighted) ==========
#   [Epoch 6 | Step 0/1162] AvgTrainLoss=0.3428
#   [Epoch 6 | Step 100/1162] AvgTrainLoss=0.3309
#   [Epoch 6 | Step 200/1162] AvgTrainLoss=0.3265
#   [Epoch 6 | Step 300/1162] AvgTrainLoss=0.3271
#   [Epoch 6 | Step 400/1162] AvgTrainLoss=0.3285
#   [Epoch 6 | Step 500/1162] AvgTrainLoss=0.3286
#   [Epoch 6 | Step 600/1162] AvgTrainLoss=0.3277
#   [Epoch 6 | Step 700/1162] AvgTrainLoss=0.3272
#   [Epoch 6 | Step 800/1162] AvgTrainLoss=0.3264
#   [Epoch 6 | Step 900/1162] AvgTrainLoss=0.3257
#   [Epoch 6 | Step 1000/1162] AvgTrainLoss=0.3256
#   [Epoch 6 | Step 1100/1162] AvgTrainLoss=0.3248
# [Epoch 006] train_loss(log-MSE)=0.3246 | val_loss(log-MSE)=0.2796 | val_MAE(hours)=61.77
#   ↳ Best weighted model updated, saved to los_multibranch_weighted_best.pt
#
# ========== Epoch 7/20 (Weighted) ==========
#   [Epoch 7 | Step 0/1162] AvgTrainLoss=0.3077
#   [Epoch 7 | Step 100/1162] AvgTrainLoss=0.3188
#   [Epoch 7 | Step 200/1162] AvgTrainLoss=0.3197
#   [Epoch 7 | Step 300/1162] AvgTrainLoss=0.3182
#   [Epoch 7 | Step 400/1162] AvgTrainLoss=0.3156
#   [Epoch 7 | Step 500/1162] AvgTrainLoss=0.3154
#   [Epoch 7 | Step 600/1162] AvgTrainLoss=0.3160
#   [Epoch 7 | Step 700/1162] AvgTrainLoss=0.3152
#   [Epoch 7 | Step 800/1162] AvgTrainLoss=0.3147
#   [Epoch 7 | Step 900/1162] AvgTrainLoss=0.3142
#   [Epoch 7 | Step 1000/1162] AvgTrainLoss=0.3138
#   [Epoch 7 | Step 1100/1162] AvgTrainLoss=0.3131
# [Epoch 007] train_loss(log-MSE)=0.3128 | val_loss(log-MSE)=0.2901 | val_MAE(hours)=63.44
#
# ========== Epoch 8/20 (Weighted) ==========
#   [Epoch 8 | Step 0/1162] AvgTrainLoss=0.3237
#   [Epoch 8 | Step 100/1162] AvgTrainLoss=0.3061
#   [Epoch 8 | Step 200/1162] AvgTrainLoss=0.3053
#   [Epoch 8 | Step 300/1162] AvgTrainLoss=0.3039
#   [Epoch 8 | Step 400/1162] AvgTrainLoss=0.3045
#   [Epoch 8 | Step 500/1162] AvgTrainLoss=0.3051
#   [Epoch 8 | Step 600/1162] AvgTrainLoss=0.3051
#   [Epoch 8 | Step 700/1162] AvgTrainLoss=0.3046
#   [Epoch 8 | Step 800/1162] AvgTrainLoss=0.3044
#   [Epoch 8 | Step 900/1162] AvgTrainLoss=0.3040
#   [Epoch 8 | Step 1000/1162] AvgTrainLoss=0.3037
#   [Epoch 8 | Step 1100/1162] AvgTrainLoss=0.3034
# [Epoch 008] train_loss(log-MSE)=0.3032 | val_loss(log-MSE)=0.2771 | val_MAE(hours)=61.73
#   ↳ Best weighted model updated, saved to los_multibranch_weighted_best.pt
#
# ========== Epoch 9/20 (Weighted) ==========
#   [Epoch 9 | Step 0/1162] AvgTrainLoss=0.3056
#   [Epoch 9 | Step 100/1162] AvgTrainLoss=0.2994
#   [Epoch 9 | Step 200/1162] AvgTrainLoss=0.3005
#   [Epoch 9 | Step 300/1162] AvgTrainLoss=0.3010
#   [Epoch 9 | Step 400/1162] AvgTrainLoss=0.2992
#   [Epoch 9 | Step 500/1162] AvgTrainLoss=0.2992
#   [Epoch 9 | Step 600/1162] AvgTrainLoss=0.2990
#   [Epoch 9 | Step 700/1162] AvgTrainLoss=0.2984
#   [Epoch 9 | Step 800/1162] AvgTrainLoss=0.2979
#   [Epoch 9 | Step 900/1162] AvgTrainLoss=0.2974
#   [Epoch 9 | Step 1000/1162] AvgTrainLoss=0.2973
#   [Epoch 9 | Step 1100/1162] AvgTrainLoss=0.2969
# [Epoch 009] train_loss(log-MSE)=0.2971 | val_loss(log-MSE)=0.2801 | val_MAE(hours)=62.14
#
# ========== Epoch 10/20 (Weighted) ==========
#   [Epoch 10 | Step 0/1162] AvgTrainLoss=0.2620
#   [Epoch 10 | Step 100/1162] AvgTrainLoss=0.2952
#   [Epoch 10 | Step 200/1162] AvgTrainLoss=0.2945
#   [Epoch 10 | Step 300/1162] AvgTrainLoss=0.2920
#   [Epoch 10 | Step 400/1162] AvgTrainLoss=0.2902
#   [Epoch 10 | Step 500/1162] AvgTrainLoss=0.2899
#   [Epoch 10 | Step 600/1162] AvgTrainLoss=0.2901
#   [Epoch 10 | Step 700/1162] AvgTrainLoss=0.2900
#   [Epoch 10 | Step 800/1162] AvgTrainLoss=0.2904
#   [Epoch 10 | Step 900/1162] AvgTrainLoss=0.2913
#   [Epoch 10 | Step 1000/1162] AvgTrainLoss=0.2915
#   [Epoch 10 | Step 1100/1162] AvgTrainLoss=0.2911
# [Epoch 010] train_loss(log-MSE)=0.2909 | val_loss(log-MSE)=0.2730 | val_MAE(hours)=61.12
#   ↳ Best weighted model updated, saved to los_multibranch_weighted_best.pt
#
# ========== Epoch 11/20 (Weighted) ==========
#   [Epoch 11 | Step 0/1162] AvgTrainLoss=0.2929
#   [Epoch 11 | Step 100/1162] AvgTrainLoss=0.2852
#   [Epoch 11 | Step 200/1162] AvgTrainLoss=0.2857
#   [Epoch 11 | Step 300/1162] AvgTrainLoss=0.2859
#   [Epoch 11 | Step 400/1162] AvgTrainLoss=0.2856
#   [Epoch 11 | Step 500/1162] AvgTrainLoss=0.2843
#   [Epoch 11 | Step 600/1162] AvgTrainLoss=0.2846
#   [Epoch 11 | Step 700/1162] AvgTrainLoss=0.2841
#   [Epoch 11 | Step 800/1162] AvgTrainLoss=0.2838
#   [Epoch 11 | Step 900/1162] AvgTrainLoss=0.2833
#   [Epoch 11 | Step 1000/1162] AvgTrainLoss=0.2834
#   [Epoch 11 | Step 1100/1162] AvgTrainLoss=0.2835
# [Epoch 011] train_loss(log-MSE)=0.2836 | val_loss(log-MSE)=0.2706 | val_MAE(hours)=60.85
#   ↳ Best weighted model updated, saved to los_multibranch_weighted_best.pt
#
# ========== Epoch 12/20 (Weighted) ==========
#   [Epoch 12 | Step 0/1162] AvgTrainLoss=0.3113
#   [Epoch 12 | Step 100/1162] AvgTrainLoss=0.2849
#   [Epoch 12 | Step 200/1162] AvgTrainLoss=0.2824
#   [Epoch 12 | Step 300/1162] AvgTrainLoss=0.2815
#   [Epoch 12 | Step 400/1162] AvgTrainLoss=0.2820
#   [Epoch 12 | Step 500/1162] AvgTrainLoss=0.2818
#   [Epoch 12 | Step 600/1162] AvgTrainLoss=0.2811
#   [Epoch 12 | Step 700/1162] AvgTrainLoss=0.2802
#   [Epoch 12 | Step 800/1162] AvgTrainLoss=0.2798
#   [Epoch 12 | Step 900/1162] AvgTrainLoss=0.2793
#   [Epoch 12 | Step 1000/1162] AvgTrainLoss=0.2792
#   [Epoch 12 | Step 1100/1162] AvgTrainLoss=0.2791
# [Epoch 012] train_loss(log-MSE)=0.2787 | val_loss(log-MSE)=0.2791 | val_MAE(hours)=62.26
#
# ========== Epoch 13/20 (Weighted) ==========
#   [Epoch 13 | Step 0/1162] AvgTrainLoss=0.2648
#   [Epoch 13 | Step 100/1162] AvgTrainLoss=0.2713
#   [Epoch 13 | Step 200/1162] AvgTrainLoss=0.2728
#   [Epoch 13 | Step 300/1162] AvgTrainLoss=0.2744
#   [Epoch 13 | Step 400/1162] AvgTrainLoss=0.2743
#   [Epoch 13 | Step 500/1162] AvgTrainLoss=0.2745
#   [Epoch 13 | Step 600/1162] AvgTrainLoss=0.2748
#   [Epoch 13 | Step 700/1162] AvgTrainLoss=0.2741
#   [Epoch 13 | Step 800/1162] AvgTrainLoss=0.2740
#   [Epoch 13 | Step 900/1162] AvgTrainLoss=0.2746
#   [Epoch 13 | Step 1000/1162] AvgTrainLoss=0.2741
#   [Epoch 13 | Step 1100/1162] AvgTrainLoss=0.2737
# [Epoch 013] train_loss(log-MSE)=0.2735 | val_loss(log-MSE)=0.2656 | val_MAE(hours)=60.19
#   ↳ Best weighted model updated, saved to los_multibranch_weighted_best.pt
#
# ========== Epoch 14/20 (Weighted) ==========
#   [Epoch 14 | Step 0/1162] AvgTrainLoss=0.2955
#   [Epoch 14 | Step 100/1162] AvgTrainLoss=0.2692
#   [Epoch 14 | Step 200/1162] AvgTrainLoss=0.2714
#   [Epoch 14 | Step 300/1162] AvgTrainLoss=0.2707
#   [Epoch 14 | Step 400/1162] AvgTrainLoss=0.2711
#   [Epoch 14 | Step 500/1162] AvgTrainLoss=0.2705
#   [Epoch 14 | Step 600/1162] AvgTrainLoss=0.2702
#   [Epoch 14 | Step 700/1162] AvgTrainLoss=0.2699
#   [Epoch 14 | Step 800/1162] AvgTrainLoss=0.2695
#   [Epoch 14 | Step 900/1162] AvgTrainLoss=0.2690
#   [Epoch 14 | Step 1000/1162] AvgTrainLoss=0.2687
#   [Epoch 14 | Step 1100/1162] AvgTrainLoss=0.2686
# [Epoch 014] train_loss(log-MSE)=0.2688 | val_loss(log-MSE)=0.2709 | val_MAE(hours)=60.88
#
# ========== Epoch 15/20 (Weighted) ==========
#   [Epoch 15 | Step 0/1162] AvgTrainLoss=0.2446
#   [Epoch 15 | Step 100/1162] AvgTrainLoss=0.2637
#   [Epoch 15 | Step 200/1162] AvgTrainLoss=0.2608
#   [Epoch 15 | Step 300/1162] AvgTrainLoss=0.2615
#   [Epoch 15 | Step 400/1162] AvgTrainLoss=0.2622
#   [Epoch 15 | Step 500/1162] AvgTrainLoss=0.2626
#   [Epoch 15 | Step 600/1162] AvgTrainLoss=0.2618
#   [Epoch 15 | Step 700/1162] AvgTrainLoss=0.2619
#   [Epoch 15 | Step 800/1162] AvgTrainLoss=0.2623
#   [Epoch 15 | Step 900/1162] AvgTrainLoss=0.2618
#   [Epoch 15 | Step 1000/1162] AvgTrainLoss=0.2618
#   [Epoch 15 | Step 1100/1162] AvgTrainLoss=0.2619
# [Epoch 015] train_loss(log-MSE)=0.2615 | val_loss(log-MSE)=0.2714 | val_MAE(hours)=61.18
#
# ========== Epoch 16/20 (Weighted) ==========
#   [Epoch 16 | Step 0/1162] AvgTrainLoss=0.2165
#   [Epoch 16 | Step 100/1162] AvgTrainLoss=0.2613
#   [Epoch 16 | Step 200/1162] AvgTrainLoss=0.2598
#   [Epoch 16 | Step 300/1162] AvgTrainLoss=0.2592
#   [Epoch 16 | Step 400/1162] AvgTrainLoss=0.2588
#   [Epoch 16 | Step 500/1162] AvgTrainLoss=0.2580
#   [Epoch 16 | Step 600/1162] AvgTrainLoss=0.2579
#   [Epoch 16 | Step 700/1162] AvgTrainLoss=0.2577
#   [Epoch 16 | Step 800/1162] AvgTrainLoss=0.2574
#   [Epoch 16 | Step 900/1162] AvgTrainLoss=0.2569
#   [Epoch 16 | Step 1000/1162] AvgTrainLoss=0.2566
#   [Epoch 16 | Step 1100/1162] AvgTrainLoss=0.2568
# [Epoch 016] train_loss(log-MSE)=0.2568 | val_loss(log-MSE)=0.2707 | val_MAE(hours)=61.18
#
# ========== Epoch 17/20 (Weighted) ==========
#   [Epoch 17 | Step 0/1162] AvgTrainLoss=0.2564
#   [Epoch 17 | Step 100/1162] AvgTrainLoss=0.2578
#   [Epoch 17 | Step 200/1162] AvgTrainLoss=0.2561
#   [Epoch 17 | Step 300/1162] AvgTrainLoss=0.2574
#   [Epoch 17 | Step 400/1162] AvgTrainLoss=0.2562
#   [Epoch 17 | Step 500/1162] AvgTrainLoss=0.2562
#   [Epoch 17 | Step 600/1162] AvgTrainLoss=0.2550
#   [Epoch 17 | Step 700/1162] AvgTrainLoss=0.2553
#   [Epoch 17 | Step 800/1162] AvgTrainLoss=0.2547
#   [Epoch 17 | Step 900/1162] AvgTrainLoss=0.2552
#   [Epoch 17 | Step 1000/1162] AvgTrainLoss=0.2545
#   [Epoch 17 | Step 1100/1162] AvgTrainLoss=0.2541
# [Epoch 017] train_loss(log-MSE)=0.2539 | val_loss(log-MSE)=0.3015 | val_MAE(hours)=66.03
#
# ========== Epoch 18/20 (Weighted) ==========
#   [Epoch 18 | Step 0/1162] AvgTrainLoss=0.2454
#   [Epoch 18 | Step 100/1162] AvgTrainLoss=0.2552
#   [Epoch 18 | Step 200/1162] AvgTrainLoss=0.2551
#   [Epoch 18 | Step 300/1162] AvgTrainLoss=0.2532
#   [Epoch 18 | Step 400/1162] AvgTrainLoss=0.2524
#   [Epoch 18 | Step 500/1162] AvgTrainLoss=0.2517
#   [Epoch 18 | Step 600/1162] AvgTrainLoss=0.2514
#   [Epoch 18 | Step 700/1162] AvgTrainLoss=0.2516
#   [Epoch 18 | Step 800/1162] AvgTrainLoss=0.2519
#   [Epoch 18 | Step 900/1162] AvgTrainLoss=0.2514
#   [Epoch 18 | Step 1000/1162] AvgTrainLoss=0.2511
#   [Epoch 18 | Step 1100/1162] AvgTrainLoss=0.2508
# [Epoch 018] train_loss(log-MSE)=0.2507 | val_loss(log-MSE)=0.2668 | val_MAE(hours)=60.48
#
# ========== Epoch 19/20 (Weighted) ==========
#   [Epoch 19 | Step 0/1162] AvgTrainLoss=0.2021
#   [Epoch 19 | Step 100/1162] AvgTrainLoss=0.2527
#   [Epoch 19 | Step 200/1162] AvgTrainLoss=0.2516
#   [Epoch 19 | Step 300/1162] AvgTrainLoss=0.2497
#   [Epoch 19 | Step 400/1162] AvgTrainLoss=0.2494
#   [Epoch 19 | Step 500/1162] AvgTrainLoss=0.2490
#   [Epoch 19 | Step 600/1162] AvgTrainLoss=0.2482
#   [Epoch 19 | Step 700/1162] AvgTrainLoss=0.2481
#   [Epoch 19 | Step 800/1162] AvgTrainLoss=0.2474
#   [Epoch 19 | Step 900/1162] AvgTrainLoss=0.2473
#   [Epoch 19 | Step 1000/1162] AvgTrainLoss=0.2467
#   [Epoch 19 | Step 1100/1162] AvgTrainLoss=0.2463
# [Epoch 019] train_loss(log-MSE)=0.2467 | val_loss(log-MSE)=0.2714 | val_MAE(hours)=61.17
#
# ========== Epoch 20/20 (Weighted) ==========
#   [Epoch 20 | Step 0/1162] AvgTrainLoss=0.2304
#   [Epoch 20 | Step 100/1162] AvgTrainLoss=0.2454
#   [Epoch 20 | Step 200/1162] AvgTrainLoss=0.2459
#   [Epoch 20 | Step 300/1162] AvgTrainLoss=0.2444
#   [Epoch 20 | Step 400/1162] AvgTrainLoss=0.2435
#   [Epoch 20 | Step 500/1162] AvgTrainLoss=0.2436
#   [Epoch 20 | Step 600/1162] AvgTrainLoss=0.2434
#   [Epoch 20 | Step 700/1162] AvgTrainLoss=0.2437
#   [Epoch 20 | Step 800/1162] AvgTrainLoss=0.2441
#   [Epoch 20 | Step 900/1162] AvgTrainLoss=0.2442
#   [Epoch 20 | Step 1000/1162] AvgTrainLoss=0.2439
#   [Epoch 20 | Step 1100/1162] AvgTrainLoss=0.2437
# [Epoch 020] train_loss(log-MSE)=0.2438 | val_loss(log-MSE)=0.2720 | val_MAE(hours)=61.97
# Weighted training finished. Best val_loss: 0.2655596495235932

# %%
best_weighted_model = MultiModalLOSModel(cfg).to(device)
best_weighted_model.load_state_dict(torch.load(best_model_path_weighted, map_location=device))
best_weighted_model.eval()

test_abs_error_sum_weighted = 0.0
test_count_weighted = 0

with torch.no_grad():
    for batch in test_loader:
        batch = {k: (v.to(device) if torch.is_tensor(v) else v)
                 for k, v in batch.items()}

        y_pred = best_weighted_model(
            age=batch["age"],
            gender_idx=batch["gender_id"],
            race_idx=batch["race_id"],
            service_idx=batch["service_id"],
            drg_code_idx=batch["drg_code_id"],
            drg_severity=batch["drg_severity"],
            drg_mortality=batch["drg_mortality"],
            diag_codes=batch["diag_codes"],
            diag_offsets=batch["diag_offsets"],
            proc_codes=batch["proc_codes"],
            proc_offsets=batch["proc_offsets"],
            med_codes=batch["med_codes"],
            med_offsets=batch["med_offsets"],
            order_codes=batch["order_codes"],
            order_offsets=batch["order_offsets"],
        )

        y_true = batch["target"]  # log(1+LOS)

        # Convert log(1+LOS) -> actual hours
        y_true_hours = torch.expm1(y_true)
        y_pred_hours = torch.expm1(y_pred)

        abs_err = torch.abs(y_pred_hours - y_true_hours)
        test_abs_error_sum_weighted += abs_err.sum().item()
        test_count_weighted += y_true.size(0)

test_mae_hours_weighted = test_abs_error_sum_weighted / test_count_weighted

print(f"\n===== Test set MAE =====")
print(f"Test MAE (hours): {test_mae_hours_weighted:.2f}")
print(f"Test MAE (days) : {test_mae_hours_weighted / 24:.2f}")
# Out:
# ===== Test set MAE =====
# Test MAE (hours): 59.72
# Test MAE (days) : 2.49

# %%
import numpy as np
import torch

best_weighted_model = MultiModalLOSModel(cfg).to(device)
best_weighted_model.load_state_dict(torch.load(best_model_path_weighted, map_location=device))
best_weighted_model.eval()

all_true_los_hours = []
all_pred_los_hours = []

best_weighted_model.eval()

with torch.no_grad():
    for batch in test_loader:
        batch = {k: (v.to(device) if torch.is_tensor(v) else v)
                 for k, v in batch.items()}

        y_pred_log = best_weighted_model(
            age=batch["age"],
            gender_idx=batch["gender_id"],
            race_idx=batch["race_id"],
            service_idx=batch["service_id"],
            drg_code_idx=batch["drg_code_id"],
            drg_severity=batch["drg_severity"],
            drg_mortality=batch["drg_mortality"],
            diag_codes=batch["diag_codes"],
            diag_offsets=batch["diag_offsets"],
            proc_codes=batch["proc_codes"],
            proc_offsets=batch["proc_offsets"],
            med_codes=batch["med_codes"],
            med_offsets=batch["med_offsets"],
            order_codes=batch["order_codes"],
            order_offsets=batch["order_offsets"],
        )

        y_true_log = batch["target"]

        # Convert log(1+LOS) to actual LOS hours
        y_true_hours = torch.expm1(y_true_log).cpu().numpy()
        y_pred_hours = torch.expm1(y_pred_log).cpu().numpy()

        all_true_los_hours.extend(y_true_hours)
        all_pred_los_hours.extend(y_pred_hours)

# Convert lists to numpy arrays
all_true_los_hours = np.array(all_true_los_hours)
all_pred_los_hours = np.array(all_pred_los_hours)

# Define LOS ranges and calculate MAE for each
los_ranges = [
    (0, 200, "0-200 hours"),
    (200, 400, "200-400 hours"),
    (400, np.inf, ">400 hours"),
]

print("\n===== MAE by LOS Range (Test Set) ====")
for lower_bound, upper_bound, label in los_ranges:
    if upper_bound == np.inf:
        mask = (all_true_los_hours >= lower_bound)
    else:
        mask = (all_true_los_hours >= lower_bound) & (all_true_los_hours < upper_bound)

    filtered_true_los = all_true_los_hours[mask]
    filtered_pred_los = all_pred_los_hours[mask]

    if len(filtered_true_los) > 0:
        mae = np.mean(np.abs(filtered_pred_los - filtered_true_los))
        print(f"  {label:15}: MAE = {mae:.2f} hours (N={len(filtered_true_los)})")
    else:
        print(f"  {label:15}: No samples in this range.")
# Out:
# ===== MAE by LOS Range (Test Set) ====
#   0-200 hours    : MAE = 31.91 hours (N=52437)
#   200-400 hours  : MAE = 106.04 hours (N=7713)
#   >400 hours     : MAE = 367.91 hours (N=3571)
